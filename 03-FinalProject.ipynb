# %% [markdown]
# # COGS 108 - Influence of smoking, EV & public transit ridership on air quality and asthma in NY, SF and Houston
#
# ## Permissions
#
# * [ X ] YES - make available
# * [  ] NO - keep private
#
# ## Link to video
# https://drive.google.com/file/d/1BPuorvppSQTWtfjeJm4PUFgdN8nIXgbp/view?usp=sharing
#
# ## Abstract
#
# This project investigated whether public transportation usage, EV adoption, and smoking prevalence are associated with air quality and asthma rates in Houston, San Francisco, and New York City, and which factor was the most influential. We hypothesized that higher transit ridership and EV adoption, combined with lower smoking rates, would predict better air quality and fewer asthma episodes and that transit would be the strongest predictor of the three.
#
# To test this, we collected annual data from 2015–2022 across all three cities for each feature and ran OLS regression models both pooled across cities and separately for each one, alongside correlation analyses for each city.
#
# Our results did not support the hypothesis. While the pooled model had a high R-squared (0.934), this was almost entirely driven by city fixed effects rather than any of our predictor variables, none of which reached statistical significance. NYC showed the most promising signal, with a strong correlation between NO2 and asthma rates, but SF and Houston were muddied by data quality issues and confounding time trends. Ultimately, eight years of data per city was not enough to draw reliable conclusions, and we think the next step would be moving to monthly data or looking at possible confounding factors to get the analysis needed to actually test these relationships properly.

# %% [markdown]
# ## Authors
# - Angela Wu: Conceptualization, Data curation, Software, Writing - original draft, Analysis and Conclusion
# - Al Mazlo: Conceptualization, Data curation, Software, Writing - review & editing,  Analysis and Conclusion
# - Sofina Yang: Conceptualization, Data curation, Software,  Analysis and Conclusion
# - Alyssia Almanza: Conceptualization, Data curation, Writing - original draft,  Analysis and Conclusion

# %% [markdown]
# ## Research Question

# %% [markdown]
# How does public transportation usage (buses and metro), smoking prevalence rates, and electric vehicle (EV) adoption influence air quality and the rate of reported asthma attacks among asthma patients in Houston, San Francisco (SF), and New York City (NYC)?

# %% [markdown]
# ## Background and Prior Work

# %% [markdown]
# ### Background:
# Air pollution is one of the leading environmental health risks worldwide, and urban transportation is a major contributor. Private vehicles, such as cars, trucks, and motorcycles, emit pollutants such as particulate matter (PM2.5 and PM10), nitrogen dioxide (NO2), carbon monoxide (CO), and volatile organic compounds (VOCs), all of which have been strongly linked to respiratory diseases, including asthma and chronic obstructive pulmonary disease (COPD). (1, 2)
#
# From the report of Asthma and Allergy Foundation of America (5), poor air quality can negatively affect everyone’s health. Research shows that air pollution can make asthma worse and trigger asthma symptoms. Air pollution includes gases, smoke from fires, volcanic ash, dust particles, emissions from transportation, and other substances that can harm the lungs.
#
# As cities grow, the concentration of vehicles increases, intensifying both traffic congestion and emissions, which has direct implications for public health. Understanding the link between transportation and air quality is crucial for policy-making aimed at improving population health.
#
# Public transportation, such as buses, metros, and high-speed rail (HSR), has long been proposed as a solution to reduce private vehicle use. Expanding public transit can enable ease of movement for lower-income individuals while lowering urban air pollution by reducing congestion and moving more people collectively without increasing operational emissions per person. (3)
#
# Other factors besides transportation also influence urban air quality and lung health, including smoking rates and adoption of EVs, which can have both positive and negative effects.
#
# Our project aims to specifically observe the link between public transportation systems and air quality and lung disease, controlling for the factors mentioned above. Some of the cities we will investigate include Houston, NYC, and SF.
#
# It is important to note that our study is observational and relies on publicly available datasets, so we cannot definitively prove causation between public transportation and air quality. Many of the factors mentioned above are interrelated, and unobservable variables may influence the results. To mitigate bias, we will examine multiple cities and control for known confounding factors as carefully as possible, aiming to produce robust, evidence-based insights.
#
#
# ### Prior Work:
# A relevant prior work is the technical report *Assessing the Impact of Air Pollution on Public Health along Transit Routes*, which examines how transportation and socioeconomic factors influence respiratory health in some major metropolitan areas, Dallas-Fort Worth and LA. The researchers applied stat techniques such as PCA and OLS to identify predictors of respiratory disease. Their findings showed strong correlations between both demographics and access to transit/automobile access to respiratory disease risk. Interestingly, populations with higher transit access were more prone to respiratory diseases. This work relates closely to our proposed project because it demonstrates a clear connection between transportation systems, air quality, and respiratory health. (3)
#
# Another study published in Environmental Health Perspectives investigated the association between traffic-related air pollution and the incidence of asthma in children living near major roadways. The researchers found that exposure to combustion-related pollutants such as nitrogen dioxide (NO2) and ozone was significantly linked to increases in asthma prevalence among children at home and school environments. By analyzing air quality data alongside health outcomes, the study showed that proximity to heavy traffic corridors is a significant predictor of respiratory health risks, particularly for vulnerable populations such as children. These findings highlight how motor vehicle emissions can contribute to asthma development, supporting the our rationale for investigating transportation factors alongside other predictors like smoking prevalence and EV usage in our project. (4)
#
# ### References:
# 1. World Health Organization. (2021). *WHO global air quality guidelines: Particulate matter (PM2.5 and PM10), ozone, nitrogen dioxide, sulfur dioxide and carbon monoxide*. [https://www.who.int/publications/i/item/9789240034228]
# 2. U.S. Environmental Protection Agency. (2019). *Integrated science assessment for particulate matter (ISA) (Final report)*. [https://iris.epa.gov/document/%26deid%3D347534]
# 3. Mattingly, S., Hyun, K. K., Rad, S. K., Arabi, M., & Famili, S. (2019). *Assessing the impact of air pollution on public health along transit routes*. Western Michigan University, Transportation Research Center for Livable Communities. [https://rosap.ntl.bts.gov/view/dot/62326]
# 4. McConnell, R., Islam, T., Shankardass, K., Jerrett, M., Lurmann, F., Gilliland, F., Peters, J., & Berhane, K. (2010). *Childhood incident asthma and traffic-related air pollution at home and school. Environmental Health Perspectives*. Environmental Health Perspectives, 118(7), 1021–1026. [https://pmc.ncbi.nlm.nih.gov/articles/PMC2920902/]
# 5. Asthma and Allergy Foundation of America. (2025) *2025 Asthma Capitals: The Most Challenging Places to Live with Asthma*. [https://aafa.org/wp-content/uploads/2025/09/aafa-2025-asthma-capitals-report.pdf]

# %% [markdown]
# ## Hypothesis

# %% [markdown]
# We hypothesize that higher adoption of sustainable transportation (greater public transit and more EV adoption) and lower smoking prevalence are associated with improved air quality in major urban areas. Also, improved air quality is associated with lower rates of asthma-related health outcomes among diagnosed astham patients.
#
# We further believe that public transportation will exhibit a stronger association with air quality variation across cities than EV adoption and smoking prevalence, given its larger contribution to urban emissions and the capacity to move a lot more people, thus reducing the emissions from less traffic mounting on the majority gasoline-car filled roads.
#
# We believe using both air quality and asthma rates as good indicators for substantial effects on general health and to try to reduce any latent variables we did not account for separately in each of those two indicators.

# %% [markdown]
# ## Data

# %% [markdown]
# ### Data Overview

# %% [markdown]
# - #### Dataset #1
#   - **Dataset Name:** California Vehicle Registrations by Fuel Type and ZIP Code
#   - **Link to the dataset:** https://lab.data.ca.gov/dataset/vehicle-fuel-type-count-by-zip-code
#   - **Number of observations:** ~4,000,000 rows (raw), 42 rows after cleaning and filtering for SF (6 fuel types × 7 years)
#   - **Number of variables:** 7 raw (date, zip_code, fuel, vehicles, make, model_year, duty), 4 after cleaning (fuel_type, year, vehicles, percentage)
#   - **Description of the variables most relevant to this project:** date (standardized registration date used to extract year), zip_code (used to filter for SF ZIP codes starting with 941), fuel (raw fuel type label), and vehicles (count of registered vehicles matching that combination of attributes).
#   - **Descriptions of any shortcomings this dataset has with respect to the project:** The California DMV does not release actual registration dates and instead standardizes them to a single date per year. The 2018 dataset only records through 1/10/2018, meaning some 2018 registrations appear in the 2019 file. Additionally, the raw dataset contains many granular and inconsistent fuel type labels that required significant normalization before analysis.
#
# - #### Dataset #2
#   - **Dataset Name:** Texas Alternatively Fueled Vehicle Registration Dataset
#   - **Link to the dataset:** https://www.txdmv.gov/sites/default/files/report-files/FY-2023-Alternatively-Fueled-Vehicle-Report.pdf
#   - **Number of observations:** 144 (18 fuel types × 8 years)
#   - **Number of variables:** 3 (fuel_type, year, registered_vehicles)
#   - **Description of the variables most relevant to this project:** fuel_type (the type of fuel used by the vehicle), year (fiscal year 2016–2023), and registered_vehicles (the total number of registered vehicles matching that fuel type for that year).
#   - **Descriptions of any shortcomings this dataset has with respect to the project:** The TxDMV does not publish county-level or city-level breakdowns by fuel type, meaning Houston-specific data is not publicly available. Texas state-level data is used as a proxy for Houston, which is a limitation given that statewide trends may not perfectly reflect Houston's urban vehicle composition. Additionally, the dataset only covers alternative fuels in detail, with gasoline and other conventional fuels reported as aggregate totals.
#
# - #### Dataset #3
#   - **Dataset Name:** U.S. Vehicle Registration Counts by State and Fuel Type (AFDC)
#   - **Link to the dataset:** https://afdc.energy.gov/vehicle-registration
#   - **Number of observations:** 468 (52 states/territories × 9 years)
#   - **Number of variables:** 14 raw (state, year, and one column per fuel type), 4 after cleaning (fuel_type, year, vehicles, percentage)
#   - **Description of the variables most relevant to this project:** state (filtered to New York as a proxy for NYC), year (2016–2024), and per-fuel-type counts including electric, plug-in hybrid, hybrid electric, gasoline, diesel, flex, and others.
#   - **Descriptions of any shortcomings this dataset has with respect to the project:** The AFDC dataset is only available at the state level, meaning NYC-specific registration data by fuel type is not available from any public source. New York state is used as a proxy for NYC, which is a limitation since the state includes large rural areas with different vehicle composition than NYC. The NY Open Data Portal DMV dataset was initially considered as a more granular alternative but was found to be unsuitable for year-over-year analysis, as it is a current snapshot of active registrations rather than a historical record, causing severe undercounting in earlier years and artificial inflation in recent years.
#
# - #### Dataset #4
#   - **Dataset Name:** FTA National Transit Database (NTD) Monthly Ridership — Calendar Year UPT
#   - **Link to the dataset:** https://www.transit.dot.gov/ntd/data-product/monthly-module-adjusted-data-release
#   - **Number of observations:** 72 (3 cities × 24 years, 2002–2025)
#   - **Number of variables:** 3 after cleaning (year, ridership, city)
#   - **Description of the variables most relevant to this project:** year (calendar year 2002–2025), ridership (total unlinked passenger trips aggregated across all transit modes and service types for each city's urbanized area), and city (Houston, NYC, or SF).
#   - **Descriptions of any shortcomings this dataset has with respect to the project:** The NTD reports ridership at the urbanized area (UZA) level rather than the city boundary level, meaning each UZA includes surrounding suburbs beyond the city limits. Additionally, ridership figures are aggregated across all modes and service types (bus, demand response, commuter bus, etc.), so mode-level breakdowns are lost after aggregation. NaN values in the raw data, indicating a mode was not yet operational or not reported in a given year, are treated as zero in the sum, which may slightly undercount ridership in early years when reporting coverage was less complete.
#
# - #### Dataset #5
#   - **Dataset Name:** Air Quality Statistics by City, 2000-2023
#   - **Link to the dataset:** https://www.epa.gov/air-trends/air-quality-cities-and-counties
#   - **Number of observations:** 1022
#   - **Number of variables:** 27
#   - **Description of the variables most relevant to this project:** Core Based Statistical Area (this shows the city location), Pollutant (NO2, O3, PM 2.5, PM 10), Trend Statistic (Weighted Annual Mean, Annual Mean, 98th Percentile), Year (2000-2023).
#   - **Descriptions of any shortcomings this dataset has with respect to the project:** This dataset measures pollutants with different trend statistics. For instance, NO2 is measured by “Annual Mean”, while PM 2.5 is measured by “Weighted Annual Mean”. The difference in measurement might mean standardizing or further processing of these statistics, or looking at these two pollutants separately. Also, “data from exceptional events are included”, so if there was a wildfire one year for instance in a city, that data is included even though it wouldn’t be an accurate measurement of air quality in general.
#
# - #### Dataset #6
#   - **Dataset Name:** Aggregated Adult Smoking Prevalence Dataset
#   - **Link to the dataset:** N/A (compiled from Houston State of Health/BRFSS, California Health Interview Survey, and NYC Environment & Health Data Portal)
#   - **Number of observations:** 49
#   - **Number of variables:** 6
#   - **Description of the variables most relevant to this project:** Geography (Harris County-TX, SF County-CA, NYC-NY), Year (2002–2024), Metric (Current Smoker % (Adults)), Source (Original data repository), Current_Smoker_Pct (point estimate ranging from $4.7\%$ to $21.7\%$), and Statistically_Unstable (boolean flag indicating statistical reliability).
#   - **Descriptions of any shortcomings this dataset has with respect to the project:** Although the metric is now unified (Adult Smoking %), temporal coverage still varies. NYC has 21 points (2002–2022), SF has 18 points (2003–2024), and Harris County has 10 points (2014–2023). While the Houston State of Health data for Harris County is more complete than previous versions, the baseline estimates ($13-18\%$) are significantly higher than modeled CDC PLACES estimates used in older versions, which should be noted if comparing against older local reports. Additionally, several points in the California data are flagged as statistically unstable due to small sample sizes.
#
# - #### Dataset #7
#     - **Dataset Name:** Multi-City Longitudinal Asthma Prevalence Dataset (SF, NYC, Houston)
#     - **Link to the dataset:**
#         - NYC: https://a816-dohbesp.nyc.gov/IndicatorPublic/data-explorer/asthma/?id=18#display=summary
#         - Houston: https://www.houstontx.gov/planning/Demographics/docs_pdfs/City-Population-Estimates-from-Census-Bureau-2020-to-2022.pdf \
#         https://www.houstonstateofhealth.com/indicators/index/view?indicatorId=79&localeId=133891&periodId=246
#         - SF: https://data.chhs.ca.gov/dataset/asthma-prevalence/resource/a440b99b-ccc6-473c-bea1-2baf36b05dbe
#     - **Number of observations:** ~40 (approximate total after expanding SF's 2-year intervals: 20 from NYC, 9 from Houston, 11 from SF).
#     - **Number of variables:** 4
#     - **Description of the variables most relevant to this project:** city (SF, NYC, or Houston), year (the calendar year of data collection, ranging from 2003–2022), age: the demographic filter used for alignment (standardized to adults 18+ years), percentage (percentage of adults reporting a diagnosis and active symptoms or a recent attack).
#     - **Descriptions of any shortcomings this dataset has with respect to the project:** The primary shortcoming is the inconsistency in how "current asthma" is defined and reported across cities. NYC measures adults who had symptoms in the last 12 months, Houston reports adults told they currently have asthma, and SF uses a 2-year pooled estimate of people who still have asthma or had an attack in the last year. This variation in methodology means "8% prevalence" in NYC might not be exactly equivalent to "8% prevalence" in Houston. Additionally, the timeframes are mismatched: NYC provides a deep historical look (starting 2003), while Houston (2014) and SF (2015) have much shorter longitudinal windows. Finally, SF's data required manual expansion from 2-year periods to yearly rows, which assumes the prevalence stayed constant across both years.

# %% [markdown]
# ### Datasets
#
# To see the code responsible for wrangling the data see `02-EDACheckpoint.ipynb`. We will simply load the processed data and build individual city dataframes (Houston, SF, NYC), which are also combined into a single dataframe for further analysis.

# %%
import pandas as pd
import importlib
from modules import eda

importlib.reload(eda)

processed = 'data/02-processed/' # directory path

# load datasets
air_quality_df = pd.read_csv(processed + 'air_quality_clean.csv')
smoking_df = pd.read_csv(processed + 'combined_smoking_data_clean.csv')
ev_df = pd.read_csv(processed + 'vehicle_registrations.csv')
asthma_df = pd.read_csv(processed + 'asthma_clean.csv')
ridership_df = pd.read_csv(processed + 'ridership.csv')

# build city dataframes
houston_df = eda.build_city_df('Houston', air_quality_df, asthma_df, smoking_df, ev_df, ridership_df, city_label='Houston')
sf_df = eda.build_city_df('San Francisco', air_quality_df, asthma_df, smoking_df, ev_df, ridership_df, city_label='SF')
ny_df = eda.build_city_df('New York', air_quality_df, asthma_df, smoking_df, ev_df, ridership_df, city_label='NYC')

# combine into single dataframe
full_df = pd.concat([houston_df, sf_df, ny_df], ignore_index=True)

# %%
full_df
# Out:
#     year   no2  asthma_pct  smoking_pct    ev_pct  ridership_count     city
# 0   2015   8.0         8.8         17.6  0.024000     8.772688e+07  Houston
# 1   2016   7.0         8.8         16.5  0.040000     8.949522e+07  Houston
# 2   2017   7.0         8.3         17.5  0.060000     8.944686e+07  Houston
# 3   2018   7.0         9.0         17.1  0.090000     9.031966e+07  Houston
# 4   2019   7.0         8.8         18.1  0.140000     9.060093e+07  Houston
# 5   2020   7.0         9.1         17.7  0.200000     5.397276e+07  Houston
# 6   2021   7.0        10.0         17.2  0.290000     4.734573e+07  Houston
# 7   2022   8.0         9.3         15.1  0.470000     6.046932e+07  Houston
# 8   2015   9.0         9.1          9.5  0.002773     4.617327e+08       SF
# 9   2016   8.0         9.1         12.2  0.004790     4.632898e+08       SF
# 10  2017   9.0         7.7         11.3  0.008277     4.505323e+08       SF
# ...

# %% [markdown]
# ## Results
#
# ### Exploratory Data Analysis
#
# To see the full EDA code see `02-EDACheckpoint.ipynb`. Below we summarize the key findings from the single-variable analysis across Houston, SF, and NYC, followed by a full multi-variable analysis for each city.

# %%
import numpy as np
import os
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker
import seaborn as sns
import statsmodels.formula.api as smf
from sklearn.preprocessing import MinMaxScaler
from modules import eda

# %% [markdown]
# ### EDA: Single Variable Analysis:

# %% [markdown]
# #### Air Quality Data - exploring trends over time and comparing air quality accross cities
#
# This EDA examines long-term trends in NO2 across three major U.S. metropolitan areas- SF, NY and Houston. By focusing on annual summary statistics, the aim is to compare overall exposure levels across cities and evaluate how pollution patterns have evolved over time.
#
# ![alt text](results/airquality1.png)
#
# The time series plots show a downward trend in NO2 across all three cities from 2000 onward. NYC begins with the highest NO2 levels but experiences substantial declines over time, suggesting improvements in emissions controls or traffic-related regulations.
#
# ![alt text](results/airquality2.png)
#
# The boxplot highlights differences in pollution levels across cities.
#
# ![alt text](results/airquality3.png)
#
# Here we can see there is one outlier for NO2

# %% [markdown]
# #### EV Registration Analysis
#
# This section explores vehicle registration data across three cities over time. The dataset breaks down registrations by fuel type (Electric, Hybrid, Diesel, Flex, and Gasoline) as both raw counts and percentage share of total registered vehicles.
#
# Since our central argument concerns EV adoption, percentage share is the primary metric used throughout. Raw counts can be misleading given the significant difference in city population and total vehicle registrations, so normalizing by share allows for a fair city-to-city comparison.
#
# We start with a broad view of how fuel type composition has shifted across all three cities. Gasoline is excluded here to better surface the trends in alternative fuels — its dominance (80%+) would otherwise compress everything else into near-invisible slivers. Each panel shows around the same time range, with a shared y-axis for direct comparison.
#
# ![alt text](results/ev1.png)
#
# Houston is dominated by Flex fuel, which has remained flat and high throughout the period, leaving little room for EV growth. SF is the opposite, where EV and Hybrid shares have grown dramatically, nearly doubling the total alternative fuel stack by 2024. NYC sits in between, with a more modest but steady climb. The lower NYC rates likely come from analyzing the whole state's registrations, including the rural parts which are less inclined to transition to alternative fuels overrall.
#
# ![alt text](results/ev2.png)
#
# SF has clearly pulled far ahead, reaching 8.43% by 2024, while Houston and NYC remain below 1.5%. What's notable is not just the gap in absolute terms but the shape of SF's curve, it slightly slows down in 2024 but is still massively ahead of the other two city's adoption rates. Houston's curve, by contrast, is nearly flat, indicating that EV adoption has barely begun in a city where Flex fuel and gasoline remain deeply the norm.
#
# ![alt text](results/ev3.png)
#
# SF's gains and losses are the largest by a big margin. NYC though shorter, follows the same trends as SF with the peek in 2023 and decrease in 2024. Houston lacks the 2024 data to examine if that trend holds true for it as well.
#
# ![alt text](results/ev4.png)
#
# The color gradient shows SF's row darkens rapidly from 2020 onward, while Houston and NYC remain in pale yellows throughout. The absence of data for SF in 2016 and 2017 is also worth noting, suggesting either data availability issues or negligible EV presence in those early years. Taken together, the heatmap serves as a useful reference for the exact figures behind the trends visualized in the charts above. NYC and Houston are very similar in pattern and are having a slower growth than SF, but consistent growth.

# %% [markdown]
# #### Smoking Prevalence Trends (2002–2024)
# This analysis examines the decline of adult smoking prevalence across three major US urban centers: Houston (Harris County), SF, and NYC.
#
# The goal of this EDA is to:
#
# 1. Visualize Temporal Trends: Compare the trajectory of smoking cessation across different geographic and policy environments.
#
# 2. Assess Data Quality: Identify how the exclusion of "statistically unstable" data points (primarily in the SF dataset) impacts the continuity of the trend lines.
#
# 3. Cross-City Comparison: Determine if the cities are converging toward a similar smoking rate or if local factors maintain significant disparities.
#
# ![alt text](results/smoking1.png)
# ![alt text](results/smoking2.png)
#
# Based on the generated visualizations, we can draw the following conclusions regarding the dataset and the public health landscape:
#
# 1. General Downward Trajectory
# All three cities exhibit a clear long-term decline in adult smoking. NYC provides the most robust historical context, showing a steady decrease from the early 2000s. The visualization confirms that urban tobacco control measures (taxes, smoking bans, etc.) have been broadly effective across different regions.
#
# 2. Geographic Disparities & Baselines
# Houston (Harris County): Despite having the shortest data series (starting in 2014), Houston maintains the highest prevalence among the three. The baseline of 13–18% is significantly higher than its coastal counterparts, suggesting different socio-economic factors or less restrictive local tobacco policies.
#
# SF & NYC: Both coastal cities show lower overall prevalence. However, SF's trend line may appear "choppy" or have gaps due to the removal of statistically unstable data points.
#
# 3. Impact of Data Limitations
# The "Unstable" Gap: By filtering out Statistically_Unstable rows, we improved the accuracy of the estimates but sacrificed temporal density in the SF subset. This highlights a trade-off: we have a cleaner "truth," but less ability to analyze year-over-year volatility in CA.
#
# The Houston Baseline Shift: As noted in the metadata, the Houston values are higher than previous CDC modeled estimates. The visualization makes this gap starkly visible, alerting researchers that comparing this dataset to older reports requires a disclaimer regarding the change in methodology (BRFSS vs. PLACES).
#
# 4. Convergence vs. Divergence
# The boxplot reveals that NYC has the widest historical variance (due to its long 21-year tracking), while Houston’s data is clustered at a higher range. There is no evidence of "convergence" yet; the gap between Houston and SF remains roughly consistent over the last decade.

# %% [markdown]
# #### Public Transportation Riderership in NYC, Houston and SF
#
# This exploratory data analysis examines public transit ridership trends over time in thre areas: SF, NYC, and Houston. By plotting annual ridership totals, the aim is to compare how transit usage differs across cities and identify major changes in ridership patterns over time.
#
# ![alt text](results/ridership1.png)
# ![alt text](results/ridership2.png)

# %% [markdown]
# Intepretation: From these graphs we can see that NY has a much higher ridership, with SF being moderate and Houston being the lowest. From the box plots, we also see there are a few outliers in NYC (probably due to covid). These patterns suggest that ridership is influenced not only by long-term urban characteristics but also by external factors, which may act as confounding factors in analyzing its relationship with environmental and health outcomes.

# %% [markdown]
# #### Asthma Dataset Analysis
#
# The following section explore the trends and variations of the asthma datasets of the three cities.
#
# ![alt text](results/asthma1.png)
#
# From the line plot above, we can see that NYC have a much lower percentage of asthma population comparing to SF and Houston. While NYC experiences a more steady trend except for the surge in 2015 and the drop in 2020 (possibly because of the Covid pandemic). Houston has the most obvious growth in terms of the percentage of asthma population, with a steady growth with some fluctuation through the time span. SF on the other hand has a similar percentage of asthma population comparing 2015 and 2022. While there is a drop in 2017, the trend grows steadily back to a similar percentage throughout the years.
#
# ![alt text](results/asthma2.png)
#
# The box plot above show how Houston has the smallest range among all three cities, while SF has the biggest difference of the highest and lowest percentage of population. The data of 2015 in NYC is identified as an outlier in this case, while 2017 and 2021 in Houston are identified as outliers.

# %% [markdown]
# ### EDA: Houston Multi-Variable Correlation and Trends (2015–2022)
# This analysis aims to explore how smoking rate, public transport ridership, and EV adoption affect asthma rate and air quality in Houston between 2015–2022.
#
# The goal of this EDA is to:
#
# 1. **Identify Co-occurrences:** Examine the pairwise correlation between each variable.
# 2. **Environmental Transition:** Compare growth in EV adoption and public transport ridership as indicators of environmental awareness.
# 3. **Correlation Between the Two Indicators:** Examine whether improvement in air quality (lower NO2) and drop in asthma rate have a negative correlation.
# 4. **Smoking and Air Quality:** Examine whether smoking rate and NO2 move together over time.

# %%
# scaled trends heatmap
cols = ['no2', 'asthma_pct', 'smoking_pct', 'ev_pct', 'ridership_count']
heatmap_data = houston_df.set_index('year')[cols]

scaler = MinMaxScaler()
standardized_df = pd.DataFrame(
    scaler.fit_transform(heatmap_data),
    index=heatmap_data.index,
    columns=heatmap_data.columns
)

plt.figure(figsize=(12, 8))
sns.heatmap(standardized_df.T, annot=True, cmap='YlGnBu', linewidths=0.5)
plt.title('Houston: Standardized Variable Trends Over Time (0 = Min, 1 = Max)', fontsize=14)
plt.xlabel('Year')
plt.ylabel('Variables')
plt.show()

# correlation heatmap
factors = houston_df[['no2', 'asthma_pct', 'smoking_pct', 'ev_pct', 'ridership_count']]
corr_matrix = factors.corr()

plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', center=0, fmt=".2f", linewidths=0.5)
plt.title('Houston: Correlation Matrix of Environmental and Health Factors (2015–2022)')
plt.show()

# ev vs ridership (dual axis)
fig, ax1 = plt.subplots(figsize=(12, 6))
plot_df = houston_df.sort_values('year')

ax1.set_xlabel('Year')
ax1.set_ylabel('EV Percentage', color='tab:blue', fontsize=12, fontweight='bold')
sns.lineplot(data=plot_df, x='year', y='ev_pct', marker='o', color='tab:blue', ax=ax1, label='EV')
ax1.tick_params(axis='y', labelcolor='tab:blue')

ax2 = ax1.twinx()
ax2.set_ylabel('Public Transport Ridership', color='tab:red', fontsize=12, fontweight='bold')
sns.lineplot(data=plot_df, x='year', y='ridership_count', marker='s', color='tab:red', ax=ax2, label='Ridership')
ax2.tick_params(axis='y', labelcolor='tab:red')

plt.title('Houston: EV vs. Public Transport Ridership Trends (2015–2022)', fontsize=14)
ax1.grid(True, alpha=0.3)
lines1, labels1 = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(lines1 + lines2, labels1 + labels2, loc='upper left')
plt.tight_layout()
plt.show()

# asthma vs no2 (dual axis)
fig, ax1 = plt.subplots(figsize=(12, 6))

ax1.set_xlabel('Year')
ax1.set_ylabel('Asthma Rate (%)', color='tab:blue', fontsize=12, fontweight='bold')
sns.lineplot(data=plot_df, x='year', y='asthma_pct', marker='o', color='tab:blue', ax=ax1, label='Asthma')
ax1.tick_params(axis='y', labelcolor='tab:blue')

ax2 = ax1.twinx()
ax2.set_ylabel('no2', color='tab:red', fontsize=12, fontweight='bold')
sns.lineplot(data=plot_df, x='year', y='no2', marker='s', color='tab:red', ax=ax2, label='no2')
ax2.tick_params(axis='y', labelcolor='tab:red')

plt.title('Houston: Asthma Rate vs. NO2 Trends (2015–2022)', fontsize=14)
ax1.grid(True, alpha=0.3)
lines1, labels1 = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(lines1 + lines2, labels1 + labels2, loc='upper left')
plt.tight_layout()
plt.show()

# smoking vs no2 (dual axis) — added for Houston
fig, ax1 = plt.subplots(figsize=(12, 6))

ax1.set_xlabel('Year')
ax1.set_ylabel('Smoking Rate (%)', color='tab:purple', fontsize=12, fontweight='bold')
sns.lineplot(data=plot_df, x='year', y='smoking_pct', marker='o', color='tab:purple', ax=ax1, label='Smoking')
ax1.tick_params(axis='y', labelcolor='tab:purple')

ax2 = ax1.twinx()
ax2.set_ylabel('no2', color='tab:orange', fontsize=12, fontweight='bold')
sns.lineplot(data=plot_df, x='year', y='no2', marker='s', color='tab:orange', ax=ax2, label='no2')
ax2.tick_params(axis='y', labelcolor='tab:orange')

plt.title('Houston: Smoking Rate vs. no2 Trends (2015–2022)', fontsize=14)
ax1.grid(True, alpha=0.3)
lines1, labels1 = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(lines1 + lines2, labels1 + labels2, loc='upper left')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Evaluation of Houston Analysis
# Based on the multi-variable dataset for Houston, we can draw the following conclusions:
#
# 1. **NO2 Data Quality Issue**
# The standardized trends heatmap immediately reveals a problem with Houston's NO2 data — it reads as 1 (max) in 2015, drops to 0 for every year from 2016–2021, then spikes back to 1 in 2022. This is almost certainly a data artifact, as NO2 levels do not realistically flatline for six consecutive years. The asthma vs. NO2 chart confirms this, showing NO2 completely flat at 7.0 from 2016–2021 before jumping to 8.0 in 2022. Any correlation involving NO2 for Houston should be interpreted with caution. This is most likely because of our choice of years, as an overal trend from 2000 to 2022 for NO2 shows a more reliable pattern.
#
# 2. **Asthma is Rising, Not Falling**
# Unlike SF, Houston shows a clear upward trend in asthma rates, climbing from 8.8% in 2015 to a peak of 10.0% in 2021 before a slight decline to 9.3% in 2022. The correlation heatmap shows a strong negative correlation between asthma and ridership (-0.82) — as transit use collapsed post-2019, asthma rates worsened, though this likely reflects shared pandemic-era dynamics rather than direct causation.
#
# 3. **EV Adoption and Ridership Moving in Opposite Directions**
# EV adoption grew steadily from near 0% in 2015 to 0.47% in 2022, while ridership collapsed in 2020 from ~90M to ~50M and never recovered. The strong negative correlation between the two (-0.76) suggests Houston is shifting toward private EV ownership rather than public transit, the opposite of what you might expect from a city becoming more environmentally aware.
#
# 4. **Smoking Rate High**
# Houston's smoking rate fluctuates between 15–18% throughout the period with no clear downward trend, in stark contrast to SF's dramatic decline. The smoking vs. NO2 chart shows no meaningful relationship, consistent with the weak correlation (-0.49) in the heatmap. Houston's smoking rate appears largely decoupled from its other environmental metrics.

# %% [markdown]
# ### EDA: SF Multi-Variable Correlation and Trends (2015–2022)
# This analysis evaluates the relationship between public health (smoking and asthma), environmental factors (air quality and EV adoption), and urban mobility (ridership) in SF.
#
# The goal of this EDA is to:
#
# 1. **Correlations:** Examine how the significant drop in smoking relates to environmental metrics like NO2 and EV adoption.
# 2. **Pandemic Impact:** Analyze the disruption of transit ridership in 2020 and its relationship with NO2 levels.
# 3. **Environmental Transition:** Track the rapid growth of EV adoption in SF and how it aligns with health trends over time.

# %%
sns.set_theme(style="whitegrid")

# correlation heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(sf_df.drop(columns="city").corr(), annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Correlation Matrix: SF Health, Environment, and Transit', fontsize=14)
plt.show()

# smoking vs ev adoption (dual axis)
fig, ax1 = plt.subplots(figsize=(12, 6))

ax1.set_xlabel('Year')
ax1.set_ylabel('Smoking Prevalence (%)', color='tab:blue', fontsize=12)
sns.lineplot(data=sf_df, x='year', y='smoking_pct', ax=ax1, color='tab:blue', marker='o')
ax1.tick_params(axis='y', labelcolor='tab:blue')

ax2 = ax1.twinx()
ax2.set_ylabel('EV Adoption (%)', color='tab:green', fontsize=12)
sns.lineplot(data=sf_df, x='year', y='ev_pct', ax=ax2, color='tab:green', marker='s')
ax2.tick_params(axis='y', labelcolor='tab:green')

plt.title('SF: Smoking Decline vs. EV Adoption Growth', fontsize=14)
fig.tight_layout()
plt.show()

# no2 vs asthma scatter
plt.figure(figsize=(10, 6))
sns.scatterplot(data=sf_df, x='no2', y='asthma_pct', hue='year', palette='viridis', s=100)
plt.title('SF: NO2 vs. Asthma Rates', fontsize=14)
plt.xlabel('NO2 (Lower is Better)')
plt.ylabel('Asthma Rate (%)')
plt.show()

# %% [markdown]
# #### Evaluation of SF Analysis
# Based on the multi-variable dataset for SF, we can draw the following conclusions:
#
# 1. Rapid Behavioral and Technological Shifts
# The dual-axis chart highlights two dramatic shifts occurring simultaneously in SF. Between 2018 and 2019, smoking prevalence dropped by more than half (from 12.1% to 5.5%). It is worth noting that smoking appears to rise from 9.5% in 2015 to 12.1% in 2018 before this drop, which may reflect a data gap rather than an actual increase given the missing years 2016 and 2017. During that same period and continuing into 2022, EV adoption grew exponentially, reaching nearly 5% of the vehicle share. This indicates a city undergoing a rapid transformation in both public health habits and technology.
#
# 2. Air Quality and Pandemic Disruption
# Like most major cities, SF saw a massive drop in transit ridership in 2020 (falling from ~445M to ~167M). Interestingly, NO2 reached its best recorded level (6.0) in 2021, coinciding with the period of lowest ridership and reduced overall activity. The correlation heatmap shows a strong positive correlation (+0.93) between ridership and NO2, meaning years with higher ridership coincide with worse air quality — the expected direction given that more urban activity produces more emissions. This suggests that the reduction in urban movement during the pandemic may have contributed to the improvement in air quality observed in 2021.
#
# 3. The Asthma Paradox
# Despite the massive reduction in smoking and general improvements in air quality, asthma rates in SF have remained somewhat "sticky," rising back to 8.8% in 2021–2022 after a dip in 2018. This suggests that respiratory health in SF may be influenced by factors outside of just cigarette smoke and particulate matter, such as regional wildfire smoke events (which often cause spikes in AQI not fully captured in annual averages) or other environmental allergens.
#
# 4. Correlation Insight
# The heatmap shows a strong negative correlation between EV adoption and smoking, which likely reflects a shared time trend rather than direct causation — both variables are moving consistently in opposite directions over the same years, which mechanically produces a high correlation. However, the strong positive correlation between smoking and NO2 (meaning higher smoking rates occur in years with worse air quality) reinforces the idea that public health and environmental health often improve in tandem.

# %% [markdown]
# ### EDA: NYC Multi-Variable Correlation and Trends (2015–2022)
# This analysis aims to explore how smoking rate, public transport ridership, and EV usage rates affect the two indicators, asthma rate and air quality, in NYC between 2015–2022.
#
# The goal of this EDA is to:
#
# 1. **Identify Co-occurrences:** Examine the pairwise correlation between each variable.
#
# 2. **Environmental Transition:** Compare whether there can be growth for both EV rate and public transport ridership, which can be an indication of higher environmental awareness.
#
# 3. **Correlation Between the Two Indicators:** Examine whether the improvement in air quality (lower NO2) and drop in asthma rate have a negative correlation.

# %%
# scaled trends heatmap
cols = ['no2', 'asthma_pct', 'smoking_pct', 'ev_pct', 'ridership_count']
heatmap_data = ny_df.set_index('year')[cols]

scaler = MinMaxScaler()
standardized_df = pd.DataFrame(
    scaler.fit_transform(heatmap_data),
    index=heatmap_data.index,
    columns=heatmap_data.columns
)

plt.figure(figsize=(12, 8))
sns.heatmap(standardized_df.T, annot=True, cmap='YlGnBu', linewidths=0.5)
plt.title('NYC: Standardized Variable Trends Over Time (0 = Min, 1 = Max)', fontsize=14)
plt.xlabel('Year')
plt.ylabel('Variables')
plt.show()

# correlation heatmap
factors = ny_df[['no2', 'asthma_pct', 'smoking_pct', 'ev_pct', 'ridership_count']]
corr_matrix = factors.corr()

plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', center=0, fmt=".2f", linewidths=0.5)
plt.title('NYC: Correlation Matrix of Environmental and Health Factors (2015–2022)')
plt.show()

# ev vs ridership (dual axis)
fig, ax1 = plt.subplots(figsize=(12, 6))
plot_df = ny_df.sort_values('year')

ax1.set_xlabel('Year')
ax1.set_ylabel('EV Percentage', color='tab:blue', fontsize=12, fontweight='bold')
sns.lineplot(data=plot_df, x='year', y='ev_pct', marker='o', color='tab:blue', ax=ax1, label='EV')
ax1.tick_params(axis='y', labelcolor='tab:blue')

ax2 = ax1.twinx()
ax2.set_ylabel('Public Transport Ridership', color='tab:red', fontsize=12, fontweight='bold')
sns.lineplot(data=plot_df, x='year', y='ridership_count', marker='s', color='tab:red', ax=ax2, label='Ridership')
ax2.tick_params(axis='y', labelcolor='tab:red')

plt.title('NYC: EV vs. Public Transport Ridership Trends (2015–2022)', fontsize=14)
ax1.grid(True, alpha=0.3)
lines1, labels1 = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(lines1 + lines2, labels1 + labels2, loc='upper left')
plt.tight_layout()
plt.show()

# asthma vs no2 (dual axis)
fig, ax1 = plt.subplots(figsize=(12, 6))

ax1.set_xlabel('Year')
ax1.set_ylabel('Asthma Rate (%)', color='tab:blue', fontsize=12, fontweight='bold')
sns.lineplot(data=plot_df, x='year', y='asthma_pct', marker='o', color='tab:blue', ax=ax1, label='Asthma')
ax1.tick_params(axis='y', labelcolor='tab:blue')

ax2 = ax1.twinx()
ax2.set_ylabel('no2', color='tab:red', fontsize=12, fontweight='bold')
sns.lineplot(data=plot_df, x='year', y='no2', marker='s', color='tab:red', ax=ax2, label='no2')
ax2.tick_params(axis='y', labelcolor='tab:red')

plt.title('NYC: Asthma Rate vs. NO2 Trends (2015–2022)', fontsize=14)
ax1.grid(True, alpha=0.3)
lines1, labels1 = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(lines1 + lines2, labels1 + labels2, loc='upper left')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Evaluation of NYC Analysis
# Based on the multi-variable dataset for NYC, we can draw the following conclusions:
#
# 1. **NO2 and Asthma Move Together**
# The correlation heatmap shows the strongest relationship in the NYC data is between NO2 and asthma rate (+0.93). The asthma vs. NO2 chart makes this visually clear — both drop sharply from 2015 to 2017, plateau through 2019, bottom out in 2020, then tick back up in 2021 before declining again in 2022. Unlike Houston, NYC's asthma trend actually tracks its air quality fairly closely, suggesting NO2 is a more meaningful driver of respiratory health here than in the other cities.
#
# 2. **Smoking and EV are Almost Perfectly Inversely Correlated**
# The heatmap shows a -0.95 correlation between smoking rate and EV adoption — the strongest pairwise relationship in the dataset across all three cities. As with SF, this almost certainly reflects a shared time trend rather than direct causation, but it does reinforce that NYC is undergoing a consistent behavioral and technological shift over this period. The standardized trends heatmap makes this especially clear: smoking goes from 1.0 in 2015 to 0 in 2022 while EV goes from 0 to 1.
#
# 3. **Pandemic Impact on Ridership**
# NYC's ridership collapse in 2020 is the most dramatic of the three cities, dropping from ~4.3B trips in 2019 to ~2.0B — a fall of more than half. By 2022 it had only recovered to ~2.8B, still well below pre-pandemic levels. The strong positive correlation between smoking and ridership (+0.81) again likely reflects the shared time trend of both declining over the period rather than any meaningful relationship.
#
# 4. **EV Adoption and Ridership Declining Together**
# Unlike Houston where EV and ridership diverge sharply, NYC shows both growing through 2019 and then both dropping in 2020. Post-pandemic, EV continues rising while ridership recovers slowly. This suggests NYC residents are not simply substituting public transit for private EVs — both modes were disrupted simultaneously and are recovering at different rates.

# %% [markdown]
# ### OLS Regression Analysis
#
# To examine which factors most meaningfully predict NO2 and asthma rates, we run two OLS regression models on the full dataset. We believe OLS is a valid model for this, as we believe there is a linear relationship between the features and outcome. We also assume these variables are independent.
#
# The first treats NO2 as the outcome, driven by smoking, EV adoption, and ridership variables. The second treats asthma rate as the outcome, adding NO2 as a predictor to check for the effect of air quality on respiratory health. City is included as a categorical variable to account for the differences across Houston, SF, and NYC.

# %%
from sklearn.preprocessing import StandardScaler
# 1. Select the columns to scale (exclude the target variable 'y')
features = ['no2', 'smoking_pct', 'ev_pct', 'ridership_count', 'asthma_pct']
scaler = StandardScaler()

# 2. Scale the data
full_df_scaled = full_df.copy()
full_df_scaled[features] = scaler.fit_transform(full_df[features])

# no2 as outcome — driven by behavior and transport
model_no2 = smf.ols('no2 ~ smoking_pct + ev_pct + ridership_count + C(city)', data=full_df_scaled).fit()
print(model_no2.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    no2   R-squared:                       0.957
# Model:                            OLS   Adj. R-squared:                  0.945
# Method:                 Least Squares   F-statistic:                     79.78
# Date:                Wed, 18 Mar 2026   Prob (F-statistic):           1.21e-11
# Time:                        19:59:36   Log-Likelihood:                 3.6545
# No. Observations:                  24   AIC:                             4.691
# Df Residuals:                      18   BIC:                             11.76
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept          -0.7886      0.257     -3.066      0.007      -1.329      -0.248
# ...

# %% [markdown]
# #### OLS Regression Results: NO2
#
# The model explains 96% of the variance in NO2 (R² = 0.961, Adjusted R² = 0.949), with an F-statistic p-value of 1.01e-10 confirming the model is highly significant. Residuals look clean with no serious normality violations.
#
# After controlling for smoking, EV adoption, and ridership, NYC has a NO2 coefficient of +5.46 (p=0.002) and SF +2.23 (p=0.044) relative to Houston as the baseline. This means where you live matters far more than any behavioral variable in predicting air quality.
#
# EV adoption comes closest to significance (p=0.076) with a negative coefficient of -0.42 (higher EV adoption is associated with lower NO2 in the expected direction), but misses the 0.05 threshold. Smoking and ridership are not statistically significant (p=0.406 and p=0.301) once city is controlled for.
#
# One thing worth noting is the large condition number (3.79e+10), which suggests multicollinearity between predictors possibly because EV adoption and ridership both trend strongly over time alongside each other.

# %%
# asthma as outcome — driven by behavior, transport, and air quality
model_asthma = smf.ols('asthma_pct ~ smoking_pct + ev_pct + ridership_count + C(city)', data=full_df_scaled).fit()
print(model_asthma.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:             asthma_pct   R-squared:                       0.930
# Model:                            OLS   Adj. R-squared:                  0.911
# Method:                 Least Squares   F-statistic:                     48.11
# Date:                Wed, 18 Mar 2026   Prob (F-statistic):           8.61e-10
# Time:                        18:12:59   Log-Likelihood:                -2.0786
# No. Observations:                  24   AIC:                             16.16
# Df Residuals:                      18   BIC:                             23.23
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept           0.9557      0.327      2.926      0.009       0.269       1.642
# ...

# %% [markdown]
# #### OLS Regression Results: Asthma Rate
#
# The asthma model also fits well overall (R² = 0.947, Adjusted R² = 0.926), with a significant F-statistic (p=9.78e-09). NYC has a coefficient of -7.14 (p=0.001) relative to Houston, meaning NYC has substantially lower asthma rates after controlling for everything else. SF's coefficient is -1.63 but was not significant (p=0.122).
#
# None of the behavioral or environmental predictors reach significance individually. NO2 has a positive coefficient of +0.34 (p=0.137), which is the expected direction (worse air quality associated with higher asthma) but is not conclusive with this sample size.
#
# Smoking, EV adoption, and ridership are all far from significant (p=0.680, 0.369, 0.565). The same multicollinearity warning applies here (condition number 3.83e+10).

# %% [markdown]
# #### OLS Regression on individual cities
#
# Since city seemed to be a major influence in the results of our OLS models above, we wanted to see within each city (geographical region) if there were linear relationships between our features and outcomes.
#
# Below are OLS models for each city and for both asthma and air quality.

# %%
from sklearn.preprocessing import StandardScaler

# asthma in New York 

# 1. Select the columns to scale (exclude the target variable 'y')
features = ['asthma_pct', 'smoking_pct', 'ev_pct', 'ridership_count']
scaler = StandardScaler()

# 2. Scale the data
ny_df_scaled = ny_df.copy()
ny_df_scaled[features] = scaler.fit_transform(ny_df_scaled[features])

model_asthma_ny = smf.ols('asthma_pct ~ smoking_pct + ev_pct + ridership_count', data=ny_df_scaled).fit()
model_asthma_ny.summary()
# Out:
# /opt/anaconda3/envs/COGS108_FA25/lib/python3.11/site-packages/scipy/stats/_axis_nan_policy.py:430: UserWarning: `kurtosistest` p-value may be inaccurate with fewer than 20 observations; only n=8 observations were given.
#   return hypotest_fun_in(*args, **kwds)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:             asthma_pct   R-squared:                       0.228
# Model:                            OLS   Adj. R-squared:                 -0.350
# Method:                 Least Squares   F-statistic:                    0.3946
# Date:                Wed, 18 Mar 2026   Prob (F-statistic):              0.765
# Time:                        23:01:36   Log-Likelihood:                -10.314
# No. Observations:                   8   AIC:                             28.63
# Df Residuals:                       4   BIC:                             28.95
# Df Model:                           3
# ...

# %%
# asthma in SF

# 1. Select the columns to scale (exclude the target variable 'y')
features = ['asthma_pct', 'smoking_pct', 'ev_pct', 'ridership_count']
scaler = StandardScaler()

# 2. Scale the data
sf_df_scaled = sf_df.copy()
sf_df_scaled[features] = scaler.fit_transform(sf_df_scaled[features])

model_asthma_sf = smf.ols('asthma_pct ~ smoking_pct + ev_pct + ridership_count', data=sf_df_scaled).fit()
model_asthma_sf.summary()
# Out:
# /opt/anaconda3/envs/COGS108_FA25/lib/python3.11/site-packages/scipy/stats/_axis_nan_policy.py:430: UserWarning: `kurtosistest` p-value may be inaccurate with fewer than 20 observations; only n=8 observations were given.
#   return hypotest_fun_in(*args, **kwds)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:             asthma_pct   R-squared:                       0.027
# Model:                            OLS   Adj. R-squared:                 -0.703
# Method:                 Least Squares   F-statistic:                   0.03661
# Date:                Wed, 18 Mar 2026   Prob (F-statistic):              0.989
# Time:                        23:01:54   Log-Likelihood:                -11.243
# No. Observations:                   8   AIC:                             30.49
# Df Residuals:                       4   BIC:                             30.80
# Df Model:                           3
# ...

# %%
# asthma in Houston 

features = ['asthma_pct', 'smoking_pct', 'ev_pct', 'ridership_count']
scaler = StandardScaler()

# 2. Scale the data
houston_df_scaled = houston_df.copy()
houston_df_scaled[features] = scaler.fit_transform(houston_df_scaled[features])

model_asthma_houston = smf.ols('asthma_pct ~ smoking_pct + ev_pct + ridership_count', data=houston_df_scaled).fit()
model_asthma_houston.summary()

model_asthma_ht = smf.ols('asthma_pct ~ smoking_pct + ev_pct + ridership_count', data=houston_df_scaled).fit()
model_asthma_ht.summary()
# Out:
# /opt/anaconda3/envs/COGS108_FA25/lib/python3.11/site-packages/scipy/stats/_axis_nan_policy.py:430: UserWarning: `kurtosistest` p-value may be inaccurate with fewer than 20 observations; only n=8 observations were given.
#   return hypotest_fun_in(*args, **kwds)
# /opt/anaconda3/envs/COGS108_FA25/lib/python3.11/site-packages/scipy/stats/_axis_nan_policy.py:430: UserWarning: `kurtosistest` p-value may be inaccurate with fewer than 20 observations; only n=8 observations were given.
#   return hypotest_fun_in(*args, **kwds)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:             asthma_pct   R-squared:                       0.670
# Model:                            OLS   Adj. R-squared:                  0.422
# Method:                 Least Squares   F-statistic:                     2.704
# Date:                Wed, 18 Mar 2026   Prob (F-statistic):              0.180
# ...

# %%
# NO2 as outcome in NY — driven by behavior and transport
model_no2_ny = smf.ols('no2 ~ smoking_pct + ev_pct + ridership_count', data=ny_df_scaled).fit()
print(model_no2_ny.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    no2   R-squared:                       0.447
# Model:                            OLS   Adj. R-squared:                  0.032
# Method:                 Least Squares   F-statistic:                     1.076
# Date:                Wed, 18 Mar 2026   Prob (F-statistic):              0.454
# Time:                        20:00:39   Log-Likelihood:                -7.4856
# No. Observations:                   8   AIC:                             22.97
# Df Residuals:                       4   BIC:                             23.29
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept          13.2500      0.308     42.965      0.000      12.394      14.106
# ...

# %%
# no2 as outcome in SF— driven by behavior and transport
model_no2_sf = smf.ols('no2 ~ smoking_pct + ev_pct + ridership_count', data=sf_df_scaled).fit()
print(model_no2_sf.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    no2   R-squared:                       0.833
# Model:                            OLS   Adj. R-squared:                  0.708
# Method:                 Least Squares   F-statistic:                     6.667
# Date:                Wed, 18 Mar 2026   Prob (F-statistic):             0.0491
# Time:                        20:01:36   Log-Likelihood:                -4.5995
# No. Observations:                   8   AIC:                             17.20
# Df Residuals:                       4   BIC:                             17.52
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept           7.8750      0.215     36.629      0.000       7.278       8.472
# ...

# %%
# no2 as outcome in Houston — driven by behavior and transport
model_no2_houston = smf.ols('no2 ~ smoking_pct + ev_pct + ridership_count', data=houston_df_scaled).fit()
print(model_no2_houston.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                    no2   R-squared:                       0.265
# Model:                            OLS   Adj. R-squared:                 -0.286
# Method:                 Least Squares   F-statistic:                    0.4811
# Date:                Wed, 18 Mar 2026   Prob (F-statistic):              0.713
# Time:                        20:01:41   Log-Likelihood:                -3.4232
# No. Observations:                   8   AIC:                             14.85
# Df Residuals:                       4   BIC:                             15.16
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept           7.2500      0.186     39.064      0.000       6.735       7.765
# ...

# %% [markdown]
# Running OLS model for each city also did not yield any significant results, as the results have high P values for each feature. We continue our analysis by looking at trends between variables, since we believe there could be multicollinearity

# %% [markdown]
# Multicollinearity, as indicated by the high Condition Number (“Cond. No.”) in our OLS results, suggests that some of our independent variables are highly correlated with each other. Multicollinearity increases the variance of the coefficient estimates, which in turn increases their standard errors. As the standard errors increase, the t-statistics decrease, making it less likely for coefficients to appear statistically significant, even if there is an underlying relationship.
# To address this, we conducted pairwise analyses to examine the relationships between individual variables without the interference of multicollinearity.

# %% [markdown]
# #### Pairwise Analysis
#
# Because our OLS models produced few statistically significant coefficients, we want to conduct pairwise analyses to further explore the relationships between individual variables. Pairwise analysis allows us to examine the association between two variables at a time, helping identify whether meaningful relationships exist before controlling for other factors.
#
# While these correlations don't imply causation, they reveal some meaningful associations between variables, such as the strong relationship between NO2 and asthma prevalence in New York and the negative relationship between EV adoption and NO2 in San Francisco. These results suggest that environmental factors may still be related to air quality and asthma outcomes even when the multivariate OLS model lacks statistical significance.

# %%
# Computing correlation matrices for each city to analyze relationships within factors. 

houston_corr = full_df[full_df["city"] == "Houston"][[
    "no2","asthma_pct","smoking_pct","ev_pct","ridership_count"
]].corr()

sf_corr = full_df[full_df["city"] == "SF"][[
    "no2","asthma_pct","smoking_pct","ev_pct","ridership_count"
]].corr()

nyc_corr = full_df[full_df["city"] == "NYC"][[
    "no2","asthma_pct","smoking_pct","ev_pct","ridership_count"
]].corr()

print("Houston correlations")
print(houston_corr)

print("San Francisco correlations")
print(sf_corr)

print("New York correlations")
print(nyc_corr)
# Out:
# Houston correlations
#                       no2  asthma_pct  smoking_pct    ev_pct  ridership_count
# no2              1.000000    0.046846    -0.494267  0.335061        -0.068205
# asthma_pct       0.046846    1.000000    -0.277856  0.667262        -0.815107
# smoking_pct     -0.494267   -0.277856     1.000000 -0.639422         0.265958
# ev_pct           0.335061    0.667262    -0.639422  1.000000        -0.762957
# ridership_count -0.068205   -0.815107     0.265958 -0.762957         1.000000
# San Francisco correlations
#                       no2  asthma_pct  smoking_pct    ev_pct  ridership_count
# no2              1.000000   -0.312263     0.761682 -0.791500         0.906242
# asthma_pct      -0.312263    1.000000    -0.056397  0.055198        -0.130749
# smoking_pct      0.761682   -0.056397     1.000000 -0.786441         0.768237
# ev_pct          -0.791500    0.055198    -0.786441  1.000000        -0.823575
# ...

# %% [markdown]
# #### Houston
#
# There are several strong relationships between transportation patterns and health indicators. The strongest correlation is the negative relationship between ridership and asthma prevalence (r = -0.82), with suggests that years with higher public transit usage are associated with lower asthma rates. EV adoption also shows a moderately strong positive correlation with asthma prevalence (r = 0.67) and a negative correlation with smoking rates (r = -0.64). These relationships likely reflect time trends rather than causal effects, as EV adoption increased over time while smoking declined. NO2 shows only weak relationships with asthma and ridership, indicating that air pollution levels in Houston may be influenced by factors beyond transportation alone.
#
# #### San Fransisco
# San Francisco shows strong relationships between transportation variables and air quality. EV adoption is strongly negatively correlated with NO2 (r = -0.81), suggesting that increased adoption of electric vehicles is associated with lower pollution levels. Similarly, ridership is strongly positively correlated with NO2 (r = 0.93), indicating that years with higher transit activity correspond to higher recorded pollution levels. Smoking prevalence also shows a strong positive correlation with NO2 (r = 0.81). In contrast, asthma prevalence has relatively weak correlations with the other variables, suggesting that factors beyond air pollution and transportation patterns may play a larger role in asthma trends within San Francisco.
#
# #### New York
#
# New York displays the strongest relationship between air quality and asthma prevalence, with NO2 and asthma showing a strong positive correlation (r = 0.93). This suggests that higher pollution levels are associated with increased asthma in the city. Smoking rates also correlate positively with both NO2 (r = 0.58) and ridership (r = 0.81), showing that periods of higher smoking occured at the same time as increased pollution. EV use shows strong negative correlations with smoking (r = -0.95) and ridership (r = -0.69), also probably reflecting long-term shifts toward cleaner transportation and declining smoking rates over time.

# %%
#graph no2 vs asthma by city

sns.lmplot(
    data=full_df,
    x="no2",
    y="asthma_pct",
    col="city",
    height=4,
    aspect=1
)

plt.subplots_adjust(top=0.85)
plt.suptitle("NO2 vs Asthma Prevalence by City")
plt.show()

# %% [markdown]
# Here, we can see a positive slope for NYC, as discussed in the analysis above

# %%
# ev adoption vs NO2 by city

sns.lmplot(
    data=full_df,
    x="ev_pct",
    y="no2",
    col="city",
    height=4,
    aspect=1
)

plt.subplots_adjust(top=0.85)
plt.suptitle("EV Adoption vs NO2 by City")
plt.show()

# %% [markdown]
# This graph also shows a negative correlation for SF's EV Adoption vs pm 2.5

# %%
sns.lmplot(
    data=full_df,
    x="smoking_pct",
    y="no2",
    col="city",
    height=4,
    aspect=1
)

plt.subplots_adjust(top=0.85)
plt.suptitle("Smoking Prevalence vs NO2 by City")
plt.show()

# %% [markdown]
# These graphs show a positive correlation between smoking and NO2 for SF and NYC.

# %% [markdown]
# In conclusion, while these graphs and the correlation matrices cannot imply causation, they still provide insight into the trends between key environmental and behavioral factors within each city. By examining pairwise relationships, we are able to observe how variables such as air quality, smoking rates, EV adoption, and public transit ridership move together over time. Although our OLS models did not produce many statistically significant results (likely due to the small sample size and potential multicollinearity among predictors), the pairwise analyses highlight a few meaningful associations. These patterns suggest that transportation behaviors may still be related to changes in air quality and asthma, even if the individual effects are difficult to isolate within a single regression model.

# %% [markdown]
# #### Multicollinearity Check

# %% [markdown]
# We want to confirm multicollinearity.
#
# The significant discrepancy in $R^2$ values between the aggregate multi-city model and the city-specific NYC model suggests that the initial high explanatory power was likely driven by the large baseline variances between the cities rather than the longitudinal trends of the independent variables. In the pooled model, the distinct 'city-level' differences in air quality, transit infrastructure, and public health created a high $R^2$ that masked potential multicollinearity among the predictors. Once the model was restricted to a single city, this 'between-group' variance was removed, revealing that the internal factors—such as EV adoption and smoking rates—move in such close correlation over time that the model cannot statistically isolate their individual impacts. This 'High $R^2$, Low Significance' pattern, coupled with the collapse of explanatory power in the isolated model, strongly indicates that the independent factors are collinear and likely confounded by a shared temporal trend.

# %% [markdown]
# By doing the variance inflation factor (VIF) test, we want to testify this hypothesis and find an explanation for the high p-values.

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
import pandas as pd

# 1. Prepare your independent variables (X)
X = full_df_scaled[['smoking_pct', 'ev_pct', 'ridership_count']]

# 2. Statsmodels VIF requires a constant (intercept) to be added manually
from statsmodels.tools.tools import add_constant
X_with_const = add_constant(X)

# 3. Calculate VIF for each feature
vif_data = pd.DataFrame()
vif_data["Feature"] = X_with_const.columns
vif_data["VIF"] = [variance_inflation_factor(X_with_const.values, i) 
                  for i in range(X_with_const.shape[1])]

print(vif_data)
# Out:
#            Feature       VIF
# 0            const  1.000000
# 1      smoking_pct  2.526212
# 2           ev_pct  2.734991
# 3  ridership_count  1.287455

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
import pandas as pd

# 1. Prepare your independent variables (X)
X = ny_df_scaled[['smoking_pct', 'ev_pct', 'ridership_count']]

# 2. Statsmodels VIF requires a constant (intercept) to be added manually
from statsmodels.tools.tools import add_constant
X_with_const = add_constant(X)

# 3. Calculate VIF for each feature
vif_data = pd.DataFrame()
vif_data["Feature"] = X_with_const.columns
vif_data["VIF"] = [variance_inflation_factor(X_with_const.values, i) 
                  for i in range(X_with_const.shape[1])]

print(vif_data)
# Out:
#            Feature        VIF
# 0            const   1.000000
# 1      smoking_pct  18.042674
# 2           ev_pct  11.989282
# 3  ridership_count   3.447020

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
import pandas as pd

# 1. Prepare your independent variables (X)
X = sf_df_scaled[['smoking_pct', 'ev_pct', 'ridership_count']]

# 2. Statsmodels VIF requires a constant (intercept) to be added manually
from statsmodels.tools.tools import add_constant
X_with_const = add_constant(X)

# 3. Calculate VIF for each feature
vif_data = pd.DataFrame()
vif_data["Feature"] = X_with_const.columns
vif_data["VIF"] = [variance_inflation_factor(X_with_const.values, i) 
                  for i in range(X_with_const.shape[1])]

print(vif_data)
# Out:
#            Feature       VIF
# 0            const  1.000000
# 1      smoking_pct  2.973143
# 2           ev_pct  3.787175
# 3  ridership_count  3.525636

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
import pandas as pd

# 1. Prepare your independent variables (X)
X = houston_df_scaled[['smoking_pct', 'ev_pct', 'ridership_count']]

# 2. Statsmodels VIF requires a constant (intercept) to be added manually
from statsmodels.tools.tools import add_constant
X_with_const = add_constant(X)

# 3. Calculate VIF for each feature
vif_data = pd.DataFrame()
vif_data["Feature"] = X_with_const.columns
vif_data["VIF"] = [variance_inflation_factor(X_with_const.values, i) 
                  for i in range(X_with_const.shape[1])]

print(vif_data)
# Out:
#            Feature       VIF
# 0            const  1.000000
# 1      smoking_pct  2.112744
# 2           ev_pct  4.698063
# 3  ridership_count  2.988605

# %% [markdown]
# ### Analysis on OLS and VIF Results

# %% [markdown]
# The high $R^2$ in the aggregate model is primarily a reflection of the massive structural and baseline differences between the three cities rather than the longitudinal impact of the independent factors. By including the "City" dummy variable, the model successfully captures the "between-city" variance—most notably the statistically significant difference between Houston and NYC (p=0.001). This indicates that the unique environmental, socioeconomic, and infrastructural characteristics of each city are the dominant predictors of asthma rates. However, once these baseline differences are accounted for, the "within-city" changes—the year-over-year shifts in EV adoption, smoking, and ridership—do not show enough unique variation to reach statistical significance. In essence, the model "knows" that being in NYC is a strong predictor of a specific asthma level, but it cannot confirm that a 1% increase in EVs in NYC specifically caused a corresponding drop in asthma over this short 8-year window.
#
# The "VIF Paradox" further clarifies why isolating a single driver is so difficult within a specific urban context like New York. While the full dataset shows low multicollinearity (VIF < 3), the NYC-specific model reveals severe collinearity between smoking rates (VIF 18.0) and EV adoption (VIF 11.9). This occurs because, within a single city, these variables often function as "temporal proxies"; as time passes, EVs steadily increase while smoking rates steadily decline. Because these factors move in nearly perfect lockstep over time, the OLS math suffers from "variance inflation," making it impossible to disentangle which factor is truly responsible for the health outcomes. Consequently, the high p-values in the models are not necessarily proof that these factors don't matter, but rather evidence that their individual effects are "smeared" together by shared trends and drowned out by the sheer magnitude of the city-level baseline.

# %% [markdown]
# While the New York City model was hindered by severe multicollinearity (High VIF), the models for Houston and San Francisco exhibited low VIF scores but failed to achieve statistical significance or high $R^2$ values. This suggests a different statistical challenge: a lack of explanatory power. In these cities, the incremental changes in EV adoption and smoking rates over the 8-year period were insufficient to overcome the 'noise' in the asthma data. This indicates that asthma fluctuations in these regions are likely driven by localized factors not captured in this dataset—such as industrial point-source emissions in Houston or geographic/climatic variances in San Francisco—rather than the broad urban trends evaluated here.

# %% [markdown]
# ## Ethics

# %% [markdown]
# ### A. Data Collection
#  - [X] **A.1 Informed consent**: If there are human subjects, have they given informed consent, where subjects affirmatively opt-in and have a clear understanding of the data uses to which they consent?
#
# > This project relies on aggregated, city-level secondary data (e.g., transportation usage, smoking rates, EV adoption, air quality metrics) rather than individual-level human subject data. Because we are not directly collecting data from individuals, informed consent is not applicable in the traditional sense. However, we acknowledge that the original data sources may have their own consent limitations, and we rely only on publicly available or ethically collected datasets.
#
#  - [X] **A.2 Collection bias**: Have we considered sources of bias that could be introduced during data collection and survey design and taken steps to mitigate those?
#
# > There are several sources of potential collection bias in this dataset. Large cities differ significantly in transportation budgets, population density, and infrastructure, which affects public transportation usage, EV adoption, and driving behavior. Denser cities may naturally rely less on private vehicles, while smoking rates may be influenced by density-related stressors or local social norms. Income-related bias is also present, as wealthier populations are more likely to own EVs and rely less on public transportation, while lower-income groups may experience higher stressors, higher smoking rates, and greater exposure to pollution. Cultural and regulatory differences (such as smoking bans or EV incentives) further bias how data is collected and reported across cities.
#
#  - [ ] **A.3 Limit PII exposure**: Have we considered ways to minimize exposure of personally identifiable information (PII) for example through anonymization or not collecting information that isn't relevant for analysis?
#  - [X] **A.4 Downstream bias mitigation**: Have we considered ways to enable testing downstream results for biased outcomes (e.g., collecting data on protected group status like race or gender)?
#
# > While individual protected attributes such as race or gender are not directly included, we acknowledge that variables like income, age, transportation access, and neighborhood-level pollution can act as proxies for protected groups. We explicitly consider these limitations and design the analysis to test outcomes across income levels and city characteristics to help identify potential downstream bias.
#
# ### B. Data Storage
#  - [X] **B.1 Data security**: Do we have a plan to protect and secure data (e.g., encryption at rest and in transit, access controls on internal users and third parties, access logs, and up-to-date software)?
#
# > All datasets are stored locally or in secure cloud-based academic environments with restricted access. Because the data is aggregated and non-PII, security risks are limited, but standard access controls and version management are still used.
#
#  - [ ] **B.2 Right to be forgotten**: Do we have a mechanism through which an individual can request their personal information be removed?
#  - [X] **B.3 Data retention plan**: Is there a schedule or plan to delete the data after it is no longer needed?
#
# > Data will be retained only for the duration of the project and any required academic review period. Afterward, datasets and derived files can be deleted or archived in anonymized form.
#
# ### C. Analysis
#  - [X] **C.1 Missing perspectives**: Have we sought to address blindspots in the analysis through engagement with relevant stakeholders (e.g., checking assumptions and discussing implications with affected communities and subject matter experts)?
#
# > We recognize that quantitative city-level data may miss lived experiences of communities most affected by asthma and lung disease, particularly lower-income populations. To reduce this blind spot, we explicitly question assumptions in the analysis and acknowledge that statistical relationships may not fully capture structural or social factors influencing health outcomes.
#
#  - [X] **C.2 Dataset bias**: Have we examined the data for possible sources of bias and taken steps to mitigate or address these biases (e.g., stereotype perpetuation, confirmation bias, imbalanced classes, or omitted confounding variables)?
#
# > We examine the dataset for imbalances, missing data, and uneven representation across cities and income groups. Confounding variables such as population density, transportation budgets, walkability, factory presence, median income, car ownership rates, smoking regulations, and EV incentives are explicitly considered to avoid overstating causal claims.
#
#  - [X] **C.3 Honest representation**: Are our visualizations, summary statistics, and reports designed to honestly represent the underlying data?
#
# > Visualizations and summary statistics are designed to reflect proportional differences across cities without exaggerating effects. We avoid specifically picking comparisons and clearly label axes, scales, and assumptions.
#
#  - [ ] **C.4 Privacy in analysis**: Have we ensured that data with PII are not used or displayed unless necessary for the analysis?
#  - [X] **C.5 Auditability**: Is the process of generating the analysis well documented and reproducible if we discover issues in the future?
#
# > The analysis process is documented step by step, including data sources, preprocessing decisions, and modeling assumptions, allowing results to be reproduced and reviewed if issues are identified later.
#
# ### D. Modeling
#  - [X] **D.1 Proxy discrimination**: Have we ensured that the model does not rely on variables or proxies for variables that are unfairly discriminatory?
#
# > We acknowledge that variables such as income, transportation access, and neighborhood pollution may act as proxies for protected characteristics. These variables are included carefully and interpreted cautiously to avoid reinforcing harmful stereotypes or implying individual-level causation.
#
#  - [X] **D.2 Fairness across groups**: Have we tested model results for fairness with respect to different affected groups (e.g., tested for disparate error rates)?
#
# > Model outputs are compared across income levels and city characteristics to check for systematic differences that could indicate unfair or biased outcomes.
#
#  - [X] **D.3 Metric selection**: Have we considered the effects of optimizing for our defined metrics and considered additional metrics?
#
# > We consider multiple evaluation metrics rather than optimizing a single outcome, recognizing that focusing on one metric could obscure harms to certain groups.
#
#  - [X] **D.4 Explainability**: Can we explain in understandable terms a decision the model made in cases where a justification is needed?
#
# > The model and its results are kept interpretable, allowing us to explain in plain language how variables such as air quality, transportation patterns, and smoking rates relate to asthma outcomes.
#
#  - [X] **D.5 Communicate limitations**: Have we communicated the shortcomings, limitations, and biases of the model to relevant stakeholders in ways that can be generally understood?
#
# > We clearly communicate that correlations identified in the model do not imply causation and that remaining biases and confounders may still influence results.
#
# ### E. Deployment
#  - [ ] **E.1 Monitoring and evaluation**: Do we have a clear plan to monitor the model and its impacts after it is deployed (e.g., performance monitoring, regular audit of sample predictions, human review of high-stakes decisions, reviewing downstream impacts of errors or low-confidence decisions, testing for concept drift)?
#  - [ ] **E.2 Redress**: Have we discussed with our organization a plan for response if users are harmed by the results (e.g., how does the data science team evaluate these cases and update analysis and models to prevent future harm)?
#  - [ ] **E.3 Roll back**: Is there a way to turn off or roll back the model in production if necessary?
#  - [X] **E.4 Unintended use**: Have we taken steps to identify and prevent unintended uses and abuse of the model and do we have a plan to monitor these once the model is deployed?
#
# > We acknowledge the risk that findings could be misused to oversimplify health disparities or place blame on certain populations. To mitigate this, we explicitly frame results as descriptive and exploratory and emphasize structural, environmental, and policy-related factors rather than individual behavior alone.

# %% [markdown]
# ## Conclusion
#
# This project asked whether public transit usage, EV adoption, and smoking prevalence are associated with air quality and asthma rates across Houston, San Francisco, and New York City  and whether transit would prove the stronger predictor compared to EVs and smoking. The short answer is that the data did not allow us to confirm or reject either hypothesis with confidence, though the results are instructive about why.
#
# The pooled model's R-squared of 0.934 looks good until you notice that city fixed effects are doing almost all of the work. Once you control for which city the data comes from, none of the individual predictors reach statistical significance. This means the differences in asthma rates and air quality between Houston, SF, and NYC are better explained by those cities simply being different places in density, climate, industrial land use, and housing stock than by their measurable differences in transit ridership, EV adoption, or smoking rates. Our hypothesis about transit being the dominant predictor could not be evaluated meaningfully under these conditions.
#
# The city-level results gave us a few interpretable signals mixed with a lot of noise. NYC came closest to supporting the air quality → asthma pathway, with a strong NO2–asthma correlation (r = 0.93), though the within-city regression remained underpowered. SF presented a paradox: smoking dropped dramatically and pandemic-era air quality improved, yet asthma rates stayed elevated, likely because wildfire smoke isn't well captured in annual NO2 averages. Houston's NO2 data appeared to flatline for six consecutive years, a likely data artifact that undermines any analysis involving air quality for that city.
#
# Transit's role was statistically insignificant in every model, though this almost certainly reflects data limitations rather than a true null effect.
#
# The most consistent finding across all three cities was that EV adoption and smoking rates are inversely correlated not because EVs cause people to quit smoking, but because both trends are moving in the same direction over time. This is a time-trend confound and a reminder that with only eight annual observations per city, distinguishing genuine associations from shared historical drift is essentially impossible.
#
# The core limitation of this work is statistical power. Eight observations per city leaves only four residual degrees of freedom per model, making standard errors enormous and significance nearly unattainable even if real effects exist. Longer time series, monthly rather than annual data, or neighborhood-level observations within a single city would all substantially improve the ability to test these hypotheses. Furthermore, covid impacted 2 years of our already short time span.
#
# Future work should also consider explicitly modeling wildfire events as a covariate for SF, and sourcing more reliable NO2 records for Houston. A difference in modeling would move the analysis from association toward something closer to causal inference. But, again, the most crucial thing our question lacks is the data needed to analyze.
